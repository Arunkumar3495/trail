# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:/Users/Admin/Downloads/archive (1)/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].fillna(29, inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.replace({'Embarked':{'S':0,'C':1,'Q':2}}, inplace = True)

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df['Embarked'].fillna(0,inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex']=df['Sex'].map({'male':0,'female':1})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(['Ticket','Fare','Name'],axis = 1, inplace = True)

# %%
df.drop('PassengerId',axis = 1,inplace = True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Embarked
# 0           0       3    0  22.0      1      0       0.0
# 1           1       1    1  38.0      1      0       1.0
# 2           1       3    1  26.0      0      0       0.0
# 3           1       1    1  35.0      1      0       0.0
# 4           0       3    0  35.0      0      0       0.0
# ..        ...     ...  ...   ...    ...    ...       ...
# 886         0       2    0  27.0      0      0       0.0
# 887         1       1    1  19.0      0      0       0.0
# 888         0       3    1  29.0      1      2       0.0
# 889         1       1    0  26.0      0      0       1.0
# 890         0       3    0  32.0      0      0       2.0
#
# [891 rows x 7 columns]

# %%
X = df.drop('Survived',axis  = 1)
Y = df['Survived']

# %%
X
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Embarked
# 0         3    0  22.0      1      0       0.0
# 1         1    1  38.0      1      0       1.0
# 2         3    1  26.0      0      0       0.0
# 3         1    1  35.0      1      0       0.0
# 4         3    0  35.0      0      0       0.0
# ..      ...  ...   ...    ...    ...       ...
# 886       2    0  27.0      0      0       0.0
# 887       1    1  19.0      0      0       0.0
# 888       3    1  29.0      1      2       0.0
# 889       1    0  26.0      0      0       1.0
# 890       3    0  32.0      0      0       2.0
#
# [891 rows x 6 columns]

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics

# %%
X_train,x_test,Y_train,y_test =train_test_split(X,Y,test_size = 0.2,random_state = 2)

# %%
print(X.shape,x_test.shape,X_train.shape)
# Out:
# (891, 6) (179, 6) (712, 6)

# %%
print(Y_train.shape)
# Out:
# (712,)

# %%
#model = LinearRegression()

# %%
#model.fit(X_train,Y_train)

# %%
#train_data_predict = model.predict(X_train)

# %%
#r2_train=metrics.r2_score(Y_train,train_data_predict)
#print('R_Sqr_value:',r2_train)

# %%
#test_data = model.predict(x_test)

# %%
#r2_test = metrics.r2_score(y_test,test_data)
#print('R_test_value:', r2_test)

# %%
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
training_data_accuracy = model.predict(X_train)

# %%
accuracy = accuracy_score(Y_train,training_data_accuracy)
print(accuracy)
# Out:
# 0.8117977528089888

# %%
test_data = model.predict(x_test)
accu = accuracy_score(y_test,test_data)
print(accu)
# Out:
# 0.7877094972067039
